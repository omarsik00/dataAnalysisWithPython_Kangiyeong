# %% [markdown]
# # 5.2 주식 분석 대시보드

# %% [markdown]
# ## 5.2.1 기본 설정 및 라이브러리 import

# %% [markdown]
# ## 5.2.2 주식 데이터 가져오기

# %% [markdown]
# ## 5.2.3 기업 정보 표시 함수

# %% [markdown]
# ## 5.2.4 주가 차트 생성 함수

# %% [markdown]
# ## 5.2.5 거래량 차트 생성 함수

# %% [markdown]
# ## 5.2.6 기술적 지표 계산 함수

# %% [markdown]
# ## 5.2.7 메인 애플리케이션 함수
