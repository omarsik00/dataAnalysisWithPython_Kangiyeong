# %% [markdown]
# # 2.1 변수와 데이터 타입

# %% [markdown]
# ## 2.1.1 변수

# %% [markdown]
# ## 2.1.2 기본 데이터 타입(자료형)

# %% [markdown]
# ### _기본 데이터 타입

# %% [markdown]
# #### __숫자: 정수 실수

# %%
#자릿수가 큰 경우 > 지수 표기법 | e3 = 10의 3승 : 지수 표기법으로 생성된 변수는 실수형으로 분류
a = 17e4
b = 17E3
c = -35.2e2
d = 275e-2
print(a, b, c, d)
# Out:
# 170000.0 17000.0 -3520.0 2.75

# %% [markdown]
# #### __불리언

# %%
a = 100 >

# %% [markdown]
# #### __숫자: 정수 실수

# %% [markdown]
# ## 2.1.3 컨테이너 자료형 - 리스트

# %% [markdown]
# ## 2.1.4 컨테이너 자료형 - 튜플과 세트

# %% [markdown]
# ## 2.1.5 컨테이너 자료형 - 딕셔너리
