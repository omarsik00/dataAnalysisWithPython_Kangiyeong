# %% [markdown]
# # 2.3 함수와 모듈

# %% [markdown]
# ## 2.3.1 함수

# %% [markdown]
# ## 2.3.2 람다식

# %% [markdown]
# ## 2.3.3 입출력(input/output)

# %% [markdown]
# ## 2.3.4 파일 입출력

# %% [markdown]
# ## 2.3.5 문자열

# %% [markdown]
# ## 2.3.6 모듈, 패키지, 클래스

# %% [markdown]
# ## 2.3.7 예외 처리
