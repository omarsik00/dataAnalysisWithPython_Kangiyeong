# %%
import sys
print("current python path: ", sys.executable)
print("installed packages check:")
import pandas as pd #pandas라는 최상위 패키지 전체, 넘파이도 마찬가지
import numpy as np
import matplotlib.pyplot as plt #matplotlib 전체를 가져온 것이 아니라, 그 안에 속한 pyplot이라는 서브모듈(하위 기능)만 가져와서 plt라는 별칭을 붙인 것
print("Pandas version:", pd.__version__)
print("Numpy version:", np.__version__)
#conda avtivate dataanalysis
# Out:
# current python path:  /opt/homebrew/anaconda3/envs/dataanalysis/bin/python
# installed packages check:
# Pandas version: 2.3.3
# Numpy version: 2.0.2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 9
#       7 print("Pandas version:", pd.__version__)
#       8 print("Numpy version:", np.__version__)
# ----> 9 print("matplotlib version:", matplotlib.__version__)
#
# NameError: name 'matplotlib' is not defined

# %%
print('Hello Python')
# Out:
# Hello Python

# %%
3+5
# Out:
# 8

# %%
# import sys
# print("current python path: ", sys.executable)
# print("installed packages check:")
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# print("Pandas version:", pd.__version__)
# print("Numpy version:", np.__version__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 lorem
#
# NameError: name 'lorem' is not defined

# %% [markdown]
# # jupyter Notebook
# ## header 2
# ### ~ 3
# ~
# ###### header5

# %% [markdown]
# # no order list *
# * 1
# * 2
# * 3
#
# # order list
# 1. 1
# 2. 2
# 3. 3

# %% [markdown]
# # 1 2 3

# %% [markdown]
# # subList
# * 1st
#   - 1-1
# 1. ㄴㅇㄴㅇ
# 2. ㄴㅇㄴㅇ₩₩.ㄴㅇ
# 3. ㄴㅇ

# %% [markdown]
# 1. ㄴㅇ
#
# ## 구분선 넣기
