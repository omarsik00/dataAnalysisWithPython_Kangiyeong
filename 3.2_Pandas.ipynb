# %% [markdown]
# # 3.2 Pandas

# %% [markdown]
# ## 3.2.1 Series와 DataFrame의 개념

# %% [markdown]
# ## 3.2.2 생성 및 삭제

# %% [markdown]
# ## 3.2.3 데이터 선택 - 인덱싱과 조건 기반 선택

# %% [markdown]
# ## 3.2.4 데이터 변환 - 파생변수 생성 및 함수 적용

# %% [markdown]
# ## 3.2.5 데이터 탐색 및 집계 연산
