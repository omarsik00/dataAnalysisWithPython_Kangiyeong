# %% [markdown]
# # 4.2 seaborn

# %% [markdown]
# ## 4.2.1 Tips 데이터셋

# %% [markdown]
# ## 4.2.2 산점도(scatterplot)

# %% [markdown]
# ## 4.2.3 회귀선(regplot)

# %% [markdown]
# ## 4.2.4 선그래프(lineplot)

# %% [markdown]
# ## 4.2.5 막대그래프(barplot)

# %% [markdown]
# ## 4.2.6 박스 플롯(boxplot), 바이올린 플롯(violinplot)

# %% [markdown]
# ## 4.2.7 히스토그램(histplot)

# %% [markdown]
# ## 4.2.8 히트맵(heatmap)
