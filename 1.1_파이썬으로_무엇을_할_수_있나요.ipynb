# %% [markdown]
# # 1.1 파이썬으로 무엇을 할 수 있나요?

# %% [markdown]
# ## 1.1.1 왜 파이썬으로 데이터 분석을 시작하는 것이 좋을까요?

# %% [markdown]
# ## 1.1.2 파이썬, 어떤 특징이 있나요?

# %% [markdown]
# ## 1.1.3 파이썬으로 무엇을 할 수 있나요?

# %% [markdown]
# ## 1.1.4 이 책을 학습하면 무엇을 할 수 있나요?
